# %%
### reading
with open('example.txt', 'r') as file:
    data = file.read()
    print(data)
# Out:
# My name is  Aimeerim
# I am learning Data Engineering now

# %%
### reading file line by line
with open('example.txt', 'r') as file:
    for line in file:
        print(line.strip())
# Out:
# My name is  Aimeerim
# I am learning Data Engineering now

# %%
### writing to a file
with open('output.txt', 'w') as file:
    file.write('This is a new file.\n')
    file.write('It contains multiple lines.\n')

# %%
### Write a file without overwriting existing content
with open('output.txt', 'a') as file:
    file.write('This line is appended to the file.\n')

# %%
### Writing a list of lines to a file
lines = ['First line\n', 'Second line\n', 'Third line\n']
with open('output.txt', 'a') as file:
    file.writelines(lines)

# %%
### Binary file operations
# Writing binary data
with open('example.bin', 'wb') as file:
    file.write(b'\x00\x01\x02\x03\x04')

# %%
### Reading binary data
with open('example.bin', 'rb') as file:
    binary_data = file.read()
    print(binary_data)
# Out:
# b'\x00\x01\x02\x03\x04'

# %%
### Writing and then reading a file
with open('example.txt', 'w') as file:
    file.write('Hello, this is a test file.\n')
    file.write('It has multiple lines of text.\n')

# %%
###Create a new directory
import os
new_directory = 'package'
os.mkdir(new_directory)
print(f"Directory '{new_directory}' created successfully.")
# Out:
# Directory 'package' created successfully.

# %%
### Listing file and directories
item_list = os.listdir('.')
print(item_list)
# Out:
# ['fileoperation.ipynb', 'example.txt', 'output.txt', 'package', 'example.bin']

# %%
### Joining Paths
import os
dir_name='folder'
file_name='file.txt'
full_path = os.path.join(dir_name, file_name)
print(full_path)
# Out:
# folder/file.txt

# %%
import os
dir_name='folder'
file_name='file.txt'
full_path = os.path.join(os.getcwd(),dir_name, file_name)
print(full_path)
# Out:
# /home/aimeerim/Desktop/dataengineering/udemy/python/pyhton-basics/FileOperators/folder/file.txt

# %%
path='example1.txt'
if os.path.exists(path):
    print(f"The file '{path}' exists.")
else:
    print(f"The file '{path}' does not exist.")
# Out:
# The file 'example1.txt' does not exist.

# %%
### Checking if a path is a file or directory
path = 'example.txt'
if os.path.isfile(path):
    print(f"'{path}' is a file.")
elif os.path.isdir(path):
    print(f"'{path}' is a directory.")
else:
    print(f"'{path}' is neither a file nor a directory.")
# Out:
# 'example.txt' is a file.

# %%
###Getting the absolute Path
relative_path = 'example.txt'
absolute_path = os.path.abspath(relative_path)
print(f"Relative Path: {relative_path}")
print(f"Absolute Path: {absolute_path}")
# Out:
# Relative Path: example.txt
# Absolute Path: /home/aimeerim/Desktop/dataengineering/udemy/python/pyhton-basics/FileOperators/example.txt
